# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data=pd.read_csv("../veritoplama/computer_data.csv")

# %%
df = pd.DataFrame()

# %%
data.head()
# Out:
#   Arttırılabilir Azami Bellek             Bağlantılar Bağlantılar (İkincil)  \
# 0                         NaN  USB - Bluetooth - HDMI                   NaN
# 1                         NaN  USB - Bluetooth - HDMI                   NaN
# 2                         NaN        Bluetooth - HDMI                   NaN
# 3                         NaN                    HDMI                   NaN
# 4                         NaN               Bluetooth                   NaN
#
#   Beden Cihaz Ağırlığı Dokunmatik Ekran Ekran Boyutu             Ekran Kartı  \
# 0   NaN   2 kg ve Altı              Yok     15,6 inç      Dahili Ekran Kartı
# 1   NaN   2 kg ve Altı              Yok     15,6 inç     AMD Radeon Graphics
# 2   NaN   2 kg ve Altı              Yok       14 inç     Intel Iris Graphics
# 3   NaN            NaN              NaN          NaN       AMD Radeon RX 550
# 4   NaN   2 kg ve Altı              Yok     15,6 inç  Intel UHD Graphics 600
#
# ...

# %%
df['Fiyat']=data['price']
df['Ekran Kartı']=data['Ekran Kartı']
df['İşlemci']=data['İşlemci Tipi']
df['İşlemci Nesli']=data['İşlemci Nesli']
df['İşlemci Modeli']=data['İşlemci Modeli']
df['Ram']=data['Ram (Sistem Belleği)']
df['Ekran Boyutu']=data['Ekran Boyutu']
df['Ekran Kartı Bellek Tipi']=data['Ekran Kartı Bellek Tipi']
df['Ekran Kartı Hafızası']=data['Ekran Kartı Hafızası']
df['Ekran Kartı Tipi']=data['Ekran Kartı Tipi']
df['Ekran Yenileme Hızı']=data['Ekran Yenileme Hızı']
df['Ekran Özelliği']=data['Ekran Özelliği']
df['Garanti Süresi']=data['Garanti Süresi']
df['Max İşlemci Hızı']=data['Maksimum İşlemci Hızı (GHz)']
df['Ram Tipi']=data['Ram (Sistem Belleği) Tipi']
df['SSD Kapasitesi']=data['SSD Kapasitesi']
df['SSD Teknolojisi']=data['SSD Teknolojisi']
df['Temel İşlemci Hızı']=data['Temel İşlemci Hızı (GHz)']
df['Çözünürlük']=data['Çözünürlük']
df['İşlemci Frekansı']=data['İşlemci Frekansı']
df['İşlemci Çekirdek Sayısı']=data['İşlemci Çekirdek Sayısı']
df['İşletim Sistemi']=data['İşletim Sistemi']

# %%
df.head()
# Out:
#        Fiyat             Ekran Kartı        İşlemci  İşlemci Nesli  \
# 0  10.499 TL      Dahili Ekran Kartı  Intel Core i5      11. Nesil
# 1  13.999 TL     AMD Radeon Graphics    AMD Ryzen 7       5. Nesil
# 2  14.999 TL     Intel Iris Graphics  Intel Core i5      11. Nesil
# 3  11.999 TL       AMD Radeon RX 550     Intel Xeon  Belirtilmemiş
# 4   6.869 TL  Intel UHD Graphics 600  Intel Celeron  Belirtilmemiş
#
#   İşlemci Modeli    Ram Ekran Boyutu Ekran Kartı Bellek Tipi  \
# 0         1135G7   8 GB     15,6 inç                  Dahili
# 1          5700U  16 GB     15,6 inç                  Dahili
# 2         1155G7   8 GB       14 inç                     DDR
# 3          X5660  32 GB          NaN                   GDDR5
# 4          N4020   4 GB     15,6 inç           Belirtilmemiş
#
#   Ekran Kartı Hafızası Ekran Kartı Tipi  ... Garanti Süresi Max İşlemci Hızı  \
# 0           Paylaşımlı           Dahili  ...          2 Yıl              NaN
# ...

# %%
for i in range(0,100):
    df["Fiyat"]=df.Fiyat.str.replace(',{}'.format(i),'')

df["Fiyat"]=df.Fiyat.str.replace(',00'.format(i),'')
df["Fiyat"]=df.Fiyat.str.replace(',01'.format(i),'')
df["Fiyat"]=df.Fiyat.str.replace(',02'.format(i),'')
df["Fiyat"]=df.Fiyat.str.replace(',03'.format(i),'')
df["Fiyat"]=df.Fiyat.str.replace(',04'.format(i),'')
df["Fiyat"]=df.Fiyat.str.replace(',05'.format(i),'')
df["Fiyat"]=df.Fiyat.str.replace(',06'.format(i),'')
df["Fiyat"]=df.Fiyat.str.replace(',07'.format(i),'')
df["Fiyat"]=df.Fiyat.str.replace(',08'.format(i),'')
df["Fiyat"]=df.Fiyat.str.replace(',09'.format(i),'')
df["Fiyat"]=df.Fiyat.str.replace('.','')
df['Fiyat'] = df['Fiyat'].str.replace(' TL', '').astype(float)
df['Ram'] = df['Ram'].str.replace(' GB', '').astype(float)

df['SSD Kapasitesi'] = df['SSD Kapasitesi'].str.replace(' GB', '')
numeric_values = pd.to_numeric(df['SSD Kapasitesi'], errors='coerce')
df = df[~numeric_values.isnull()]
df['SSD Kapasitesi'] = numeric_values.astype(float)

# %%
df.to_csv("../veritoplama/dfComputer_data.csv",index=False)

# %%
x= df.iloc[:,0:8].values
y= df.iloc[:,8].values
y=y.reshape(-1,1)

# %%
df['Ekran Kartı'].value_counts()
# Out:
# Ekran Kartı
# Nvidia GeForce RTX 3050       62
# AMD Radeon RX 550             54
# Intel UHD Graphics            52
# Dahili Ekran Kartı            46
# Intel Iris Graphics           43
#                               ..
# Intel UHD Graphics 620         1
# AMD Radeon R3                  1
# M2 Pro 19 Çekirdekli           1
# AMD Radeon RX 6800M            1
# Nvidia GeForce RTX 4070 Ti     1
# Name: count, Length: 66, dtype: int64

# %%
df['İşlemci'].value_counts()
# Out:
# İşlemci
# Intel Core i5    329
# AMD Ryzen 5      132
# Intel Core i7     78
# Intel Core i3     45
# AMD Ryzen 7       37
# Intel Celeron     21
# M2                 8
# Apple M1           7
# AMD Ryzen 3        6
# Apple M2           6
# Intel Core i9      5
# MediaTek P60T      5
# AMD Athlon         4
# AMD Ryzen 9        3
# AMD                3
# Intel Xeon         3
# Intel Core M       2
# Intel Atom         2
# M3                 2
# Apple M2 Pro       1
# AMD E              1
# AMD A6             1
# Ryzen Z1           1
# Intel Pentium      1
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
enc=LabelEncoder()

# %%
df["İşlemci"]=enc.fit_transform(df["İşlemci"])
df["Ekran Kartı"]=enc.fit_transform(df["Ekran Kartı"])
df["İşlemci Nesli"]=enc.fit_transform(df["İşlemci Nesli"])
df["İşlemci Modeli"]=enc.fit_transform(df["İşlemci Modeli"])
df["Ekran Boyutu"]=enc.fit_transform(df["Ekran Boyutu"])
df["Ekran Kartı Bellek Tipi"]=enc.fit_transform(df["Ekran Kartı Bellek Tipi"])
df["Ekran Kartı Hafızası"]=enc.fit_transform(df["Ekran Kartı Hafızası"])
df["Ekran Kartı Tipi"]=enc.fit_transform(df["Ekran Kartı Tipi"])
df["Ekran Yenileme Hızı"]=enc.fit_transform(df["Ekran Yenileme Hızı"])
df["Garanti Süresi"]=enc.fit_transform(df["Garanti Süresi"])
df["Ram Tipi"]=enc.fit_transform(df["Ram Tipi"])
df["Çözünürlük"]=enc.fit_transform(df["Çözünürlük"])
df["İşlemci Çekirdek Sayısı"]=enc.fit_transform(df["İşlemci Çekirdek Sayısı"])
df["İşletim Sistemi"]=enc.fit_transform(df["İşletim Sistemi"])

# %%
'''
columns = ['Fiyat','Ekran Kartı','İşlemci','İşlemci Nesli','İşlemci Modeli','Ram','Ekran Boyutu',
           'Ekran Kartı Bellek Tipi ','Ekran Kartı Hafızası','Ekran Kartı Tipi','Ekran Yenileme Hızı',
           'Garanti Süresi','Ram Tipi ','SSD Kapasitesi','Temel İşlemci Hızı','Çözünürlük',
           'İşlemci Çekirdek Sayısı','İşletim Sistemi']

columns = ['Fiyat','Ram','Ekran Boyutu',
           'Ekran Kartı Hafızası','Ekran Yenileme Hızı',
           'Garanti Süresi','SSD Kapasitesi','Temel İşlemci Hızı','Çözünürlük',
           'İşlemci Çekirdek Sayısı'] 
           '''
# Out:
# "\ncolumns = ['Fiyat','Ekran Kartı','İşlemci','İşlemci Nesli','İşlemci Modeli','Ram','Ekran Boyutu',\n           'Ekran Kartı Bellek Tipi ','Ekran Kartı Hafızası','Ekran Kartı Tipi','Ekran Yenileme Hızı',\n           'Garanti Süresi','Ram Tipi ','SSD Kapasitesi','Temel İşlemci Hızı','Çözünürlük',\n           'İşlemci Çekirdek Sayısı','İşletim Sistemi']\n\ncolumns = ['Fiyat','Ram','Ekran Boyutu',\n           'Ekran Kartı Hafızası','Ekran Yenileme Hızı',\n           'Garanti Süresi','SSD Kapasitesi','Temel İşlemci Hızı','Çözünürlük',\n           'İşlemci Çekirdek Sayısı'] \n           "

# %%
df.shape
# Out:
# (703, 22)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 703 entries, 0 to 1007
# Data columns (total 22 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Fiyat                    703 non-null    float64
#  1   Ekran Kartı              703 non-null    int32
#  2   İşlemci                  703 non-null    int32
#  3   İşlemci Nesli            703 non-null    int32
#  4   İşlemci Modeli           703 non-null    int32
#  5   Ram                      702 non-null    float64
#  6   Ekran Boyutu             703 non-null    int32
#  7   Ekran Kartı Bellek Tipi  703 non-null    int32
#  8   Ekran Kartı Hafızası     703 non-null    int32
#  9   Ekran Kartı Tipi         703 non-null    int32
#  10  Ekran Yenileme Hızı      703 non-null    int32
#  11  Ekran Özelliği           7 non-null      object
#  12  Garanti Süresi           703 non-null    int32
#  13  Max İşlemci Hızı         136 non-null    float64
# ...

# %%
df
# Out:
#          Fiyat  Ekran Kartı  İşlemci  İşlemci Nesli  İşlemci Modeli   Ram  \
# 0      10499.0           18       15              2              11   8.0
# 1      13999.0            2        6              8              66  16.0
# 2      14999.0           22       15              2              17   8.0
# 3      11999.0            8       19             13             105  32.0
# 4       6869.0           25       12             13              98   4.0
# ...        ...          ...      ...            ...             ...   ...
# 1002   14050.0           17       11              8             106   2.0
# 1003   20264.0           37       15              1               6  32.0
# 1005  152233.0           43       22              8              56  36.0
# 1006   11949.0           12        5              8             102  16.0
# 1007    5369.0           61       15             13              44  16.0
#
#       Ekran Boyutu  Ekran Kartı Bellek Tipi  Ekran Kartı Hafızası  \
# ...

# %%
df.describe()
# Out:
#               Fiyat  Ekran Kartı     İşlemci  İşlemci Nesli  İşlemci Modeli  \
# count  7.030000e+02   703.000000  703.000000     703.000000      703.000000
# mean   4.498135e+04    30.901849   12.328592       6.007112       56.093883
# std    9.883138e+04    18.533646    4.681158       4.216195       35.731346
# min    3.849000e+03     0.000000    0.000000       0.000000        0.000000
# 25%    1.134900e+04    18.000000    6.000000       3.000000       24.000000
# 50%    1.724900e+04    27.000000   15.000000       6.000000       49.000000
# 75%    3.199900e+04    48.000000   15.000000       8.000000       94.000000
# max    1.744523e+06    66.000000   23.000000      16.000000      112.000000
#
#               Ram  Ekran Boyutu  Ekran Kartı Bellek Tipi  \
# count  702.000000    703.000000               703.000000
# mean    14.809117     16.005690                 5.559033
# std      8.455845      8.165662                 2.752699
# ...

# %%
df.isna().sum()
# Out:
# Fiyat                        0
# Ekran Kartı                  0
# İşlemci                      0
# İşlemci Nesli                0
# İşlemci Modeli               0
# Ram                          1
# Ekran Boyutu                 0
# Ekran Kartı Bellek Tipi      0
# Ekran Kartı Hafızası         0
# Ekran Kartı Tipi             0
# Ekran Yenileme Hızı          0
# Ekran Özelliği             696
# Garanti Süresi               0
# Max İşlemci Hızı           567
# Ram Tipi                     0
# SSD Kapasitesi               0
# SSD Teknolojisi            647
# Temel İşlemci Hızı         331
# Çözünürlük                   0
# İşlemci Frekansı           443
# İşlemci Çekirdek Sayısı      0
# İşletim Sistemi              0
# dtype: int64

# %%
df['Temel İşlemci Hızı']
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       2.9
# 4       1.1
#        ...
# 1002    1.4
# 1003    2.9
# 1005    NaN
# 1006    3.6
# 1007    3.1
# Name: Temel İşlemci Hızı, Length: 703, dtype: object

# %%
df=df.drop(["SSD Teknolojisi"],axis=1)
df=df.drop(["Ekran Özelliği"],axis=1)
df=df.drop(["Max İşlemci Hızı"],axis=1)
df=df.drop(["Garanti Süresi"],axis=1)
df=df.drop(["İşlemci Frekansı"],axis=1)

# %%
df['Temel İşlemci Hızı'].fillna(0, inplace=True)
df['Temel İşlemci Hızı'] = pd.to_numeric(df['Temel İşlemci Hızı'], errors='coerce')
df['Temel İşlemci Hızı'].fillna(df['Temel İşlemci Hızı'].mean(), inplace=True)

# %%
df.isna().sum()
# Out:
# Fiyat                      0
# Ekran Kartı                0
# İşlemci                    0
# İşlemci Nesli              0
# İşlemci Modeli             0
# Ram                        1
# Ekran Boyutu               0
# Ekran Kartı Bellek Tipi    0
# Ekran Kartı Hafızası       0
# Ekran Kartı Tipi           0
# Ekran Yenileme Hızı        0
# Ram Tipi                   0
# SSD Kapasitesi             0
# Temel İşlemci Hızı         0
# Çözünürlük                 0
# İşlemci Çekirdek Sayısı    0
# İşletim Sistemi            0
# dtype: int64

# %%
df
# Out:
#          Fiyat  Ekran Kartı  İşlemci  İşlemci Nesli  İşlemci Modeli   Ram  \
# 0      10499.0           18       15              2              11   8.0
# 1      13999.0            2        6              8              66  16.0
# 2      14999.0           22       15              2              17   8.0
# 3      11999.0            8       19             13             105  32.0
# 4       6869.0           25       12             13              98   4.0
# ...        ...          ...      ...            ...             ...   ...
# 1002   14050.0           17       11              8             106   2.0
# 1003   20264.0           37       15              1               6  32.0
# 1005  152233.0           43       22              8              56  36.0
# 1006   11949.0           12        5              8             102  16.0
# 1007    5369.0           61       15             13              44  16.0
#
#       Ekran Boyutu  Ekran Kartı Bellek Tipi  Ekran Kartı Hafızası  \
# ...

# %%
columns = ['Fiyat','Ram',
           'SSD Kapasitesi','Temel İşlemci Hızı']

def distplot(nrows,ncols,columns):
    rows=nrows
    cols=ncols
    fig,ax=plt.subplots(nrows=rows,ncols=cols,figsize=(18,12))
    columns = columns
    index=0

    for i in range(rows):
        for j in range(cols):
            if index < len(columns):
                sns.distplot(df[columns[index]], ax=ax[i][j], bins=40)
                index += 1
            else:
                break
distplot(2,2,columns)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_38380\3000916827.py:14: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[columns[index]], ax=ax[i][j], bins=40)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_38380\3000916827.py:14: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
plt.figure()
plt.hist(df['Fiyat'],bins=70)
plt.show()

# %%
plt.hist(np.log1p(df['Fiyat']), bins=90)
plt.xlabel('Logaritmik Fiyat')
plt.ylabel('Frekans')
# Out:
# Text(0, 0.5, 'Frekans')

# %%
df[df['Fiyat']>=15000].shape
# Out:
# (404, 17)

# %%
plt.figure(figsize=(15,7))
corr_matrix=df.corr()
sns.heatmap(corr_matrix,annot=True,cmap='YlGnBu')
# Out:
# <Axes: >

# %%
corr_matrix['Fiyat'].sort_values(ascending=False)
# Out:
# Fiyat                      1.000000
# Ekran Kartı                0.099048
# SSD Kapasitesi             0.092619
# Ekran Kartı Tipi           0.056777
# Ekran Kartı Hafızası       0.053803
# Ram                        0.051625
# Ekran Kartı Bellek Tipi    0.047292
# İşlemci                    0.040201
# Çözünürlük                 0.007778
# Ekran Boyutu              -0.005591
# İşlemci Nesli             -0.012166
# Ram Tipi                  -0.017100
# İşlemci Çekirdek Sayısı   -0.041917
# İşlemci Modeli            -0.050658
# İşletim Sistemi           -0.064887
# Ekran Yenileme Hızı       -0.078499
# Temel İşlemci Hızı        -0.085045
# Name: Fiyat, dtype: float64

# %%
df.plot(kind='scatter', x='Ekran Kartı', y='İşlemci', alpha=0.4, label='Fiyat',
        figsize=(10,7), c='Fiyat', s=df['Fiyat']/100, cmap=plt.get_cmap('viridis'))

plt.legend()

# %%
df.isna().sum()
# Out:
# Fiyat                      0
# Ekran Kartı                0
# İşlemci                    0
# İşlemci Nesli              0
# İşlemci Modeli             0
# Ram                        1
# Ekran Boyutu               0
# Ekran Kartı Bellek Tipi    0
# Ekran Kartı Hafızası       0
# Ekran Kartı Tipi           0
# Ekran Yenileme Hızı        0
# Ram Tipi                   0
# SSD Kapasitesi             0
# Temel İşlemci Hızı         0
# Çözünürlük                 0
# İşlemci Çekirdek Sayısı    0
# İşletim Sistemi            0
# dtype: int64

# %%
df.dropna(axis=0,inplace=True)
df.isna().sum()
# Out:
# Fiyat                      0
# Ekran Kartı                0
# İşlemci                    0
# İşlemci Nesli              0
# İşlemci Modeli             0
# Ram                        0
# Ekran Boyutu               0
# Ekran Kartı Bellek Tipi    0
# Ekran Kartı Hafızası       0
# Ekran Kartı Tipi           0
# Ekran Yenileme Hızı        0
# Ram Tipi                   0
# SSD Kapasitesi             0
# Temel İşlemci Hızı         0
# Çözünürlük                 0
# İşlemci Çekirdek Sayısı    0
# İşletim Sistemi            0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
labelEncoder = LabelEncoder()
print(df['İşlemci'].value_counts())
df['İşlemci']=labelEncoder.fit_transform(df['İşlemci'])
print(df['İşlemci'].value_counts())
df.describe()
# Out:
# İşlemci
# 15    329
# 5     132
# 16     78
# 14     45
# 6      37
# 12     21
# 20      8
# 8       6
# 4       6
# 9       6
# 17      5
# 22      5
# 2       4
# 7       3
# 0       3
# 19      3
# 13      2
# 11      2
# 21      2
# 10      1
# 3       1
# 1       1
# 23      1
# 18      1
# Name: count, dtype: int64
# İşlemci
# 15    329
# 5     132
# 16     78
# 14     45
# 6      37
# 12     21
# 20      8
# 8       6
# 4       6
# 9       6
# 17      5
# 22      5
# 2       4
# 7       3
# 0       3
# 19      3
# 13      2
# 11      2
# 21      2
# 10      1
# 3       1
# 1       1
# 23      1
# 18      1
# Name: count, dtype: int64
#               Fiyat  Ekran Kartı     İşlemci  İşlemci Nesli  İşlemci Modeli  \
# count  7.020000e+02   702.000000  702.000000     702.000000      702.000000
# mean   4.501694e+04    30.851852   12.334758       5.992877       56.014245
# std    9.889734e+04    18.499358    4.681638       4.202262       35.694333
# ...

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
#from sklearn.feature_selection import SelectKBest, f_classif,chi2
#from sklearn.preprocessing import MinMaxScaler,StandardScaler
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

# %%
from sklearn.linear_model import LinearRegression
x= df.drop(['Fiyat'],axis=1)
y=df['Fiyat']
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

print("x_train:",x_train.shape)
print("y_test:",x_test.shape)
print("y_train:",y_train.shape)
print("y_test:",y_test.shape)

lr=LinearRegression()
lr.fit(x_train,y_train)
y_predict=lr.predict(x_test)

print('mean absolute error:',mean_absolute_error(y_test,y_predict))
print('root mean squared error:',np.sqrt(mean_squared_error(y_test,y_predict)))
print('Coefficient of Determination R^2:',r2_score(y_test,y_predict))

fig=plt.figure(figsize=(12,6))
result=pd.DataFrame({'Predicted':y_predict,'Actual':y_test})
result=result.reset_index()
result=result.drop(['index'],axis=1)
plt.plot(result[:100])
plt.legend(['Actual','Predicted'])
plt.title('Actual vs Predicted')
plt.show()
# Out:
# x_train: (561, 16)
# y_test: (141, 16)
# y_train: (561,)
# y_test: (141,)
# mean absolute error: 35426.665766866485
# root mean squared error: 42371.177553329406
# Coefficient of Determination R^2: -0.6715547433119429

# %%
from sklearn.tree import DecisionTreeRegressor
dt=DecisionTreeRegressor(criterion='squared_error',splitter='best')
dt.fit(x_train,y_train)
y_predict_dt = dt.predict(x_test)
print('mean absolute error:',mean_absolute_error(y_test,y_predict_dt))
print('root mean squared error:',np.sqrt(mean_squared_error(y_test,y_predict_dt)))
print('Coefficient of Determination R^2:',r2_score(y_test,y_predict_dt))

fig=plt.figure(figsize=(12,6))
result=pd.DataFrame({'Predicted':y_predict_dt,'Actual':y_test})
result=result.reset_index()
result=result.drop(['index'],axis=1)
plt.plot(result[:100])
plt.legend(['Actual','Predicted'])
plt.title('Actual vs Predicted')
plt.show()
# Out:
# mean absolute error: 35017.5390070922
# root mean squared error: 95656.69422741793
# Coefficient of Determination R^2: -7.519424782874987

# %%
from sklearn.linear_model import Lasso
lasso=Lasso(alpha=0.001)
lasso.fit(x_train,y_train)
y_predict_lasso = lasso.predict(x_test)
print('mean absolute error:',mean_absolute_error(y_test,y_predict_lasso))
print('root mean squared error:',np.sqrt(mean_squared_error(y_test,y_predict_lasso)))
print('Coefficient of Determination R^2:',r2_score(y_test,y_predict_lasso))

fig=plt.figure(figsize=(12,6))
result=pd.DataFrame({'Predicted':y_predict_lasso,'Actual':y_test})
result=result.reset_index()
result=result.drop(['index'],axis=1)
plt.plot(result[:100])
plt.legend(['Actual','Predicted'])
plt.title('Actual vs Predicted')
plt.show()
# Out:
# mean absolute error: 35307.81162467805
# root mean squared error: 42261.74651248083
# Coefficient of Determination R^2: -0.6629317229291305

# %%
from sklearn.ensemble import RandomForestRegressor
rf=RandomForestRegressor()
rf.fit(x_train,y_train)
y_predict_rf = rf.predict(x_test)
print('mean absolute error:',mean_absolute_error(y_test,y_predict_rf))
print('root mean squared error:',np.sqrt(mean_squared_error(y_test,y_predict_rf)))
print('Coefficient of Determination R^2:',r2_score(y_test,y_predict_rf))

fig=plt.figure(figsize=(12,6))
result=pd.DataFrame({'Predicted':y_predict_rf,'Actual':y_test})
result=result.reset_index()
result=result.drop(['index'],axis=1)
plt.plot(result[:100])
plt.legend(['Actual','Predicted'])
plt.title('Actual vs Predicted')
plt.show()
# Out:
# mean absolute error: 30252.426087132728
# root mean squared error: 64868.463715013575
# Coefficient of Determination R^2: -2.917840595020279

# %%
from sklearn.svm import SVR
svr = SVR(kernel='linear')  
svr.fit(x_train, y_train)
y_predict_svr = svr.predict(x_test)
print('mean absolute error:', mean_absolute_error(y_test, y_predict_svr))
print('root mean squared error:', np.sqrt(mean_squared_error(y_test, y_predict_svr)))
print('Coefficient of Determination R^2:', r2_score(y_test, y_predict_svr))

fig = plt.figure(figsize=(12, 6))
result = pd.DataFrame({'Predicted': y_predict_svr, 'Actual': y_test})
result = result.reset_index()
result = result.drop(['index'], axis=1)
plt.plot(result[:100])
plt.legend(['Actual', 'Predicted'])
plt.title('Actual vs Predicted')
plt.show()
# Out:
# mean absolute error: 14263.587142741062
# root mean squared error: 33485.14072035671
# Coefficient of Determination R^2: -0.04395984307658618

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline

poly_reg = make_pipeline(PolynomialFeatures(degree=2), LinearRegression())
poly_reg.fit(x_train, y_train)
y_predict_poly = poly_reg.predict(x_test)
print('mean absolute error:', mean_absolute_error(y_test, y_predict_poly))
print('root mean squared error:', np.sqrt(mean_squared_error(y_test, y_predict_poly)))
print('Coefficient of Determination R^2:', r2_score(y_test, y_predict_poly))

fig = plt.figure(figsize=(12, 6))
result = pd.DataFrame({'Predicted': y_predict_poly, 'Actual': y_test})
result = result.reset_index()
result = result.drop(['index'], axis=1)
plt.plot(result[:100])
plt.legend(['Actual', 'Predicted'])
plt.title('Actual vs Predicted')
plt.show()
# Out:
# mean absolute error: 66057.14201019504
# root mean squared error: 93439.50397352295
# Coefficient of Determination R^2: -7.129064795799209

# %%
from sklearn.ensemble import GradientBoostingRegressor
gb = GradientBoostingRegressor()
gb.fit(x_train, y_train)
y_predict_gb = gb.predict(x_test)
# Tahmin performansı değerlendirme
print('mean absolute error:', mean_absolute_error(y_test, y_predict_gb))
print('root mean squared error:', np.sqrt(mean_squared_error(y_test, y_predict_gb)))
print('Coefficient of Determination R^2:', r2_score(y_test, y_predict_gb))
# Tahminlerin görselleştirilmesi
fig = plt.figure(figsize=(12, 6))
result = pd.DataFrame({'Predicted': y_predict_gb, 'Actual': y_test})
result = result.reset_index()
result = result.drop(['index'], axis=1)
plt.plot(result[:100])
plt.legend(['Actual', 'Predicted'])
plt.title('Actual vs Predicted')
plt.show()
# Out:
# mean absolute error: 32676.489861671475
# root mean squared error: 68141.24045109026
# Coefficient of Determination R^2: -3.3231430586264246

# %%
final_RMSE = pd.DataFrame(data=[[42261.746751567895, 101780.56214166014, 42261.74651248083, 62181.25450023084, 33485.03626185988, 93439.50397352295, 64924.91193714521],
                                [-0.6629317417445129, -8.645155350308498, -0.6629317229291305, -2.5999668029118634, -0.0439533297214969, -7.129064795799209, -2.924662133486763]],
                          columns=['LinearRegression', 'DecisionTree', 'Lasso', 'RandomForest', 'SVR', 'Polynomial Regression', 'GradientBoostingTrees'],
                          index=['RMSE', 'R2'])

final_RMSE = final_RMSE.T

cm = sns.light_palette('green', as_cmap=True)

final_RMSE = final_RMSE.style.background_gradient(cmap=cm)
final_RMSE
# Out:
# <style type="text/css">
# #T_de0d6_row0_col0, #T_de0d6_row2_col0 {
#   background-color: #cde5cd;
#   color: #000000;
# }
# #T_de0d6_row0_col1, #T_de0d6_row2_col1 {
#   background-color: #118811;
#   color: #f1f1f1;
# }
# #T_de0d6_row1_col0, #T_de0d6_row4_col1 {
#   background-color: #008000;
#   color: #f1f1f1;
# }
# #T_de0d6_row1_col1, #T_de0d6_row4_col0 {
#   background-color: #ebf3eb;
#   color: #000000;
# }
# #T_de0d6_row3_col0 {
#   background-color: #88c388;
#   color: #000000;
# }
# #T_de0d6_row3_col1 {
#   background-color: #46a246;
#   color: #f1f1f1;
# }
# #T_de0d6_row5_col0 {
#   background-color: #1d8e1d;
#   color: #f1f1f1;
# }
# #T_de0d6_row5_col1 {
#   background-color: #c1dfc1;
#   color: #000000;
# }
# #T_de0d6_row6_col0 {
#   background-color: #7fbe7f;
#   color: #000000;
# }
# #T_de0d6_row6_col1 {
#   background-color: #4ea64e;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_de0d6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
# ...

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

params_grid = {
    'C': [0.1, 1, 10, 100],
    'epsilon': [0.01, 0.1, 0.2, 0.5],
    'kernel': ['linear', 'rbf', 'poly'],
    'gamma': ['scale', 'auto', 0.1, 0.01],
    'degree': [2, 3, 4],
    'coef0': [0.0, 0.1, 0.5],
    'shrinking': [True, False]
}

svr_model = SVR()

grid_search = GridSearchCV(estimator=svr_model, param_grid=params_grid, verbose=1, cv=3)
grid_search.fit(x_train, y_train)

print("En iyi parametreler:", grid_search.best_params_)

y_pred = grid_search.predict(x_test)
# Out:
# Fitting 3 folds for each of 3456 candidates, totalling 10368 fits

# %%
best_params = {'C': 10, 'gamma': 'scale', 'kernel': 'linear'}
svr = SVR(**best_params)

# Modeli eğit
svr.fit(x_train, y_train)

# Tahmin yap
y_predict_svr = svr.predict(x_test)

import joblib as jb
jb.dump(svr,'../servisleme/svr_model.sav')


# Performans metriklerini yazdır
print('Mean Absolute Error:', mean_absolute_error(y_test, y_predict_svr))
print('Root Mean Squared Error:', np.sqrt(mean_squared_error(y_test, y_predict_svr)))
print('Coefficient of Determination R^2:', r2_score(y_test, y_predict_svr))

# Tahminleri görselleştir
fig = plt.figure(figsize=(12, 6))
result = pd.DataFrame({'Predicted': y_predict_svr, 'Actual': y_test})
result = result.reset_index()
result = result.drop(['index'], axis=1)
plt.plot(result[:100])
plt.legend(['Actual', 'Predicted'])
plt.title('Actual vs Predicted')
plt.show()
#onceki degerler: RMSE:33485.03626185988   R^2: -0.0439533297214969
